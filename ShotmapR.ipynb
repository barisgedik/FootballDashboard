# %% [markdown]
# <a href="https://colab.research.google.com/github/barisgedik/BarisMatchDashboard/blob/main/ShotmapR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
library(worldfootballR)
library(ggplot2)
library(ggsoccer)
library(ggimage)

shots <- understat_player_shots(player_url = "https://understat.com/player/7322")
shots <- filter(shots, season=="2024")

shots$X <- shots$X*100
shots$Y <- shots$Y*100
shots$Y <- 100-shot$Y

ggplot(shots) +
  aes(x = X, y = Y) +
  annotate_pitch(fill = "gray15") +
  geom_point(aes(colour = result, size = xG)) +
  coord_flip(xlim = c(50,100),
             ylim = c(0,100)) +
  theme_pitch()+
  labs(title = "Bukayo Saka",
       subtitle = "Shot Locations 2024/2025: EPL",
       caption = "Data: Understat | Baris Efe Gedik",
       size = "Non-Penalty xG") +
  scale_colour_manual(values = c("#FCAB10", "#44AF69", "#F8333C", "#2B9EB3", "blue"),
                      name = "Shot Outcome",
                      labels = c("Blocked", "Goal", "Missed", "Saved", "Shot On Post"))+
  geom_point(data = shots %>%
               filter(result=="Goal"),
             aes(x = X, y = Y,
                 size = xG),
             shape = 21,
             fill = "#44AF69",
             stroke = 0.6,
             colour = "white") +
  theme(plot.title = element_text(vjust = -0.1, colour = "white", size = 16),
        plot.subtitle = element_text(colour = "white", size = 10),
        plot.caption = element_text(colour = "white"),
        panel.background = element_rect(fill = "gray15"),
        plot.background = element_rect(fill = "gray15"),
        legend.background = element_rect(fill = "gray15"),
        legend.title = element_text(colour = "white", face = "bold"),
        legend.text = element_text(colour = "white", face = "bold")) +
  geom_image(
    data = tibble(X = 91, Y = 89.5),
    aes(image = "C:/Users/baris/Desktop/Arsenal_Football_Club.png"),
    size = 0.2)
ggsave("saka_shots.png", width = 8, height = 6, dpi = 600, bg = "gray15")
